# %%
import pandas as pd
from fedot.api.main import Fedot
from fedot.core.pipelines.pipeline_builder import PipelineBuilder

# %%
path = "../datasets-offline/playground-series-s3e23"

train = pd.read_csv(f'{path}/train.csv')
test = pd.read_csv(f'{path}/test.csv')
sub = pd.read_csv(f'{path}/sample_submission.csv')

# %%
train.drop(columns=["id"], inplace=True)
test.drop(columns=["id"], inplace=True)

# %%
from sklearn.model_selection import train_test_split

train, valid = train_test_split(train, train_size=0.85, random_state=42)

# %%
auto_model = Fedot(
    problem="classification",
    metric=["precision", "accuracy", "roc_auc"],
    preset="best_quality",
    with_tuning=True,
    timeout=5,
    cv_folds=10,
    seed=42,
    n_jobs=4,
    logging_level=10,
    initial_assumption=PipelineBuilder()
    .add_node(
        "xgboost",
    )
    .build(),
    use_pipelines_cache=False,
    use_auto_preprocessing=False
)

# %%
auto_model.fit(features=train, target="defects")
# Out:
# 2024-06-24 12:39:15,124 - AssumptionsHandler - Initial pipeline fitting started
# 2024-06-24 12:39:15,136 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:39:16,956 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:39:17,003 - AssumptionsHandler - Initial pipeline was fitted successfully
# 2024-06-24 12:39:17,006 - AssumptionsHandler - Memory consumption for fitting of the initial pipeline in main session: current 43.4 MiB, max: 111.7 MiB
# 2024-06-24 12:39:17,008 - ApiComposer - Initial pipeline was fitted in 3.8 sec.
# 2024-06-24 12:39:17,019 - ApiComposer - AutoML configured. Parameters tuning: True. Time limit: 5 min. Set of candidate models: ['bernb', 'catboost', 'dt', 'fast_ica', 'isolation_forest_class', 'knn', 'lgbm', 'logit', 'mlp', 'normalization', 'pca', 'poly_features', 'qda', 'resample', 'rf', 'scaling'].
# 2024-06-24 12:39:17,043 - type - Random State: random.getstate() follows...
# (3, (2147483648, 3564348608, 1266698288, 4212342371, 3595291661, 3180588708, 3037210256, 946923017, 2565409715, 2900535780, 924383152, 4180157270, 4230508198, 2039675917, 3755350407, 2362848650, 2818100609, 2097423432, 524478045, 540883378, 281170210, 1485176884, 1493190386, 1773214509, 380915208, 3667698522, 2648371337, 2961234806, 3857480267, 1582950522, 246289694, 3322185604, 1944574775, 302623699, 169865066, 1143540808, 3733177770, 513116636, 1411153081, 3205493053, 768926902, 549624109, 1470655403, 59539609, 3678480009, 3087139671, 1176835859, 2078491503, 2299934332, 1592059249, 1062716176, 2654193596, 3531838733, 2661260596, 3881209635, 2106865768, 4154287292, 2082185616, 2301197011, 2177349827, 3082181756, 1787663536, 3714670796, 3018262113, 1670056238, 1856738750, 99824592, 2279837081, 1414647942, 3416675731, 3458782472, 3997022236, 468762002, 2666158583, 953353270, 1788980658, 3802061067, 407586584, 1844776834, 1906917274, 3154715663, 3028370222, 4156024188, 3996363428, 80495456, 2659800972, 2005649973, 3818358673, 3952623596, 2506862371, 3282302532, 263923435, 3384662671, 3292439172, 3119957588, 1224426111, 899864150, 215262826, 1619647231, 3347694949, 3497868538, 2029552053, 2992804824, 4080010250, 2023513186, 1885979437, 3564622190, 3775424
#          45488075, 3474982924, 1750873825, 2246019159,  125388929,
#        1110287838,  652200437, 4212247716, 2702974687, 2963764270,
#         208692058, 3170393729, 1378248367,  752591527,  591629541,
#        2253399388, 2402291226, 3089656189, 3202324513, 3818308310,
#        2828131601, 2690672008, 3676629884, 1007739430, 4072247562,
#        3574795162,  518485611, 1889402182, 3687902739, 3410263649,
#        2790674620,  779455241, 3573984673, 3053204735, 4089925351,
#         789980683,  476440431, 3843536868, 2400661309, 3139919094,
#        1643266656,  113318754,  428163528, 2386492935, 3807242009,
#         574560611, 3174039857, 3774465602, 1164640969,  455942925,
#        1374407495, 2562304709, 1024844203,  521375136,  417432138,
#        1203241821, 2900988280, 2841030991, 2301700751,  369508560,
#        2396447808, 1891459643, 4225682708, 3930667846, 1518293357,
#        2697063889, 3113075061, 2411136298, 2836361984, 4105335811,
#         914081338, 2675982621, 1816939127, 1596754123, 1464603632,
#        1598478676, 1318403529, 4016663081, 2106416852, 2757323084,
#        2042842122, 1175184796, 2212339255, 1334626864, 3994484893,
#        3938045599, 2166620630, 3036360431,  397499085,  975931950,
#        1868702836, 3530424696, 3532548823, 2770836469, 3537418693,
#        3344319345, 3208552526, 1771170897, 4097379814, 3761572528,
#        2794194423,  706836738, 2953105956, 3446096217,  220984542,
#         309619699,  223913021, 3985142640, 1757616575, 2582763607,
#        4018329835, 1393278443, 4121569718, 2087146446, 4282833425,
#         807775617, 1396604749, 3571181413,   90301352, 2618014643,
#        2783561793, 1329389532,  836540831,   26719530], dtype=uint32), 624, 0, 0.0)
# 2024-06-24 12:39:17,058 - ApiComposer - Pipeline composition started.
# 2024-06-24 12:39:17,063 - DataSourceSplitter - K-folds cross validation is applied.
# Generations:   0%|          | 0/10000 [00:00<?, ?gen/s]
# 2024-06-24 12:39:17,070 - MultiprocessingDispatcher - Number of used CPU's: 4
# 2024-06-24 12:39:33,426 - Unknown integration target:
# 2024-06-24 12:39:36,499 - Unknown integration target:
# 2024-06-24 12:39:39,630 - Unknown integration target:
# 2024-06-24 12:39:42,698 - Unknown integration target:
# 2024-06-24 12:39:45,913 - Unknown integration target:
# 2024-06-24 12:39:52,744 - Unknown integration target:
# 2024-06-24 12:39:59,607 - Unknown integration target:
# 2024-06-24 12:40:06,659 - Unknown integration target:
# 2024-06-24 12:40:07,294 - Unknown integration target:
# 2024-06-24 12:40:07,294 - Unknown integration target:
# 2024-06-24 12:40:29,001 - MultiprocessingDispatcher - 1 individuals out of 1 in previous population were evaluated successfully.
# 2024-06-24 12:40:29,011 - EvoGraphOptimizer - Generation num: 1 size: 1
# 2024-06-24 12:40:29,014 - EvoGraphOptimizer - Best individuals: ParetoFront archive fitness (1): ['<precision=-0.638 accuracy=-0.811 roc_auc=-0.783>']
# 2024-06-24 12:40:29,236 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_pca.
# 2024-06-24 12:40:29,244 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_scaling.
# 2024-06-24 12:40:29,270 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_fast_ica;)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:29,329 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_fast_ica;)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:29,538 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_scaling.
# 2024-06-24 12:40:29,546 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_resample.
# 2024-06-24 12:40:29,575 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_resample_{'balance': 'expand_minority', 'replace': False, 'balance_ratio': 1};)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:29,608 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_resample_{'balance': 'expand_minority', 'replace': False, 'balance_ratio': 1};)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:29,616 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_scaling.
# 2024-06-24 12:40:29,659 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_poly_features;)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:29,807 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_pca.
# 2024-06-24 12:40:30,070 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=((/n_normalization;)/n_fast_ica;)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,101 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_resample_{'balance': 'expand_minority', 'replace': False, 'balance_ratio': 1};)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,125 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_scaling.
# 2024-06-24 12:40:30,211 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_resample_{'balance': 'expand_minority', 'replace': False, 'balance_ratio': 1};)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,258 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_resample_{'balance': 'expand_minority', 'replace': False, 'balance_ratio': 1};)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,266 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_isolation_forest_class.
# 2024-06-24 12:40:30,308 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_scaling.
# 2024-06-24 12:40:30,316 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_fast_ica.
# 2024-06-24 12:40:30,396 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_resample_{'balance': 'expand_minority', 'replace': False, 'balance_ratio': 1};)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,426 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_resample_{'balance': 'expand_minority', 'replace': False, 'balance_ratio': 1};)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,454 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_normalization;)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,463 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_pca.
# 2024-06-24 12:40:30,600 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=((/n_fast_ica;)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0};)/n_dt.
# 2024-06-24 12:40:30,609 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_normalization.
# 2024-06-24 12:40:30,730 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=(/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0};)/n_poly_features.
# 2024-06-24 12:40:30,830 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Current pipeline can not solve multitask problem> for rule=<function has_no_conflicts_during_multitask at 0x7a3750e555a0> on graph=(/n_normalization;)/n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0}.
# 2024-06-24 12:40:30,856 - GraphVerifier - Graph verification failed with error <Invalid pipeline configuration: Root operation is not a model> for rule=<function has_final_operation_as_model at 0x7a3750e54f70> on graph=/n_scaling.
# 2024-06-24 12:40:31,004 - MultiprocessingDispatcher - Number of used CPU's: 4
# 2024-06-24 12:40:53,949 - Unknown integration target:
# 2024-06-24 12:40:54,026 - Unknown integration target:
# 2024-06-24 12:40:54,767 - Unknown integration target:
# 2024-06-24 12:40:57,987 - Unknown integration target:
# 2024-06-24 12:40:58,102 - Unknown integration target:
# 2024-06-24 12:40:58,905 - Unknown integration target:
# 2024-06-24 12:41:02,048 - Unknown integration target:
# 2024-06-24 12:41:02,216 - Unknown integration target:
# 2024-06-24 12:41:03,048 - Unknown integration target:
# 2024-06-24 12:41:06,021 - Unknown integration target:
# 2024-06-24 12:41:06,229 - Unknown integration target:
# 2024-06-24 12:41:07,093 - Unknown integration target:
# 2024-06-24 12:41:10,037 - Unknown integration target:
# 2024-06-24 12:41:10,285 - Unknown integration target:
# 2024-06-24 12:41:11,202 - Unknown integration target:
# 2024-06-24 12:41:18,757 - Unknown integration target:
# 2024-06-24 12:41:19,157 - Unknown integration target:
# 2024-06-24 12:41:20,307 - Unknown integration target:
# 2024-06-24 12:41:28,165 - Unknown integration target:
# 2024-06-24 12:41:28,167 - Unknown integration target:
# 2024-06-24 12:41:29,707 - Unknown integration target:
# 2024-06-24 12:41:36,973 - Unknown integration target:
# 2024-06-24 12:41:37,044 - Unknown integration target:
# 2024-06-24 12:41:37,844 - Unknown integration target:
# 2024-06-24 12:41:37,845 - Unknown integration target:
# 2024-06-24 12:41:37,899 - Unknown integration target:
# 2024-06-24 12:41:37,900 - Unknown integration target:
# 2024-06-24 12:41:38,585 - Unknown integration target:
# 2024-06-24 12:41:39,410 - Unknown integration target:
# 2024-06-24 12:41:39,411 - Unknown integration target:
# 2024-06-24 12:42:23,184 - MultiprocessingDispatcher - 11 individuals out of 21 in previous population were evaluated successfully.
# 2024-06-24 12:42:23,209 - EvoGraphOptimizer - Generation num: 2 size: 11
# 2024-06-24 12:42:23,212 - EvoGraphOptimizer - Best individuals: ParetoFront archive fitness (4): ['<precision=-0.725 accuracy=-0.803 roc_auc=-0.788>', '<precision=-0.703 accuracy=-0.809 roc_auc=-0.792>', '<precision=-0.656 accuracy=-0.814 roc_auc=-0.790>', '<precision=-0.649 accuracy=-0.813 roc_auc=-0.790>']
# 2024-06-24 12:42:23,215 - GroupedCondition - Optimisation stopped: Time limit is reached
# Generations:   0%|          | 0/10000 [03:06<?, ?gen/s]
# 2024-06-24 12:42:23,219 - OptimisationTimer - Composition time: 3.103 min
# 2024-06-24 12:42:23,222 - OptimisationTimer - Algorithm was terminated due to processing time limit
# 2024-06-24 12:42:23,235 - EvoGraphOptimizer - Generation num: 3 size: 4
# 2024-06-24 12:42:23,239 - EvoGraphOptimizer - Best individuals: ParetoFront archive fitness (4): ['<precision=-0.725 accuracy=-0.803 roc_auc=-0.788>', '<precision=-0.703 accuracy=-0.809 roc_auc=-0.792>', '<precision=-0.656 accuracy=-0.814 roc_auc=-0.790>', '<precision=-0.649 accuracy=-0.813 roc_auc=-0.790>']
# 2024-06-24 12:42:23,240 - EvoGraphOptimizer - no improvements for 1 iterations
# 2024-06-24 12:42:23,243 - EvoGraphOptimizer - spent time: 3.1 min
# 2024-06-24 12:42:23,250 - GPComposer - GP composition finished
# 2024-06-24 12:42:23,258 - DataSourceSplitter - K-folds cross validation is applied.
# 2024-06-24 12:42:23,261 - ApiComposer - Hyperparameters tuning started with 2 min. timeout
# 2024-06-24 12:42:23,265 - SimultaneousTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2024-06-24 12:42:23,270 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5} fit started
# 2024-06-24 12:42:23,314 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:25,243 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:25,302 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:27,235 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:27,295 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:29,218 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:29,265 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:31,175 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:31,222 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:33,128 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:33,174 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:35,093 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:35,138 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:37,050 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:37,096 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:39,019 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:39,066 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:40,982 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:41,030 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:42,942 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:42,966 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5} with evaluated metrics: (-0.7252151180777898,)
# 2024-06-24 12:42:42,970 - SimultaneousTuner - Initial graph: {'depth': 1, 'length': 1, 'nodes': [xgboost]}
# xgboost - {'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5}
# Initial metric: [0.725]
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]2024-06-24 12:42:42,993 - build_posterior_wrapper took 0.007611 seconds
# 2024-06-24 12:42:42,995 - TPE using 0 trials
# 2024-06-24 12:42:43,004 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5} fit started
# 2024-06-24 12:42:43,039 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:44,949 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:44,996 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:46,903 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:46,949 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:48,906 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:48,952 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:50,865 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:50,911 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:52,813 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:52,858 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:54,782 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:54,827 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:56,782 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:56,829 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:42:58,800 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:42:58,846 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:00,770 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:00,819 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:02,737 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:02,760 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5} with evaluated metrics: (-0.7252151180777898,)
# 100%|██████████| 1/1 [00:19<00:00, 19.78s/trial, best loss: -0.7252151180777898]
#   0%|          | 1/100000 [00:00<?, ?trial/s, best loss=?]2024-06-24 12:43:02,793 - build_posterior_wrapper took 0.007329 seconds
# 2024-06-24 12:43:02,796 - TPE using 1/1 trials with best loss -0.725215
# 2024-06-24 12:43:02,803 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 6, 'learning_rate': 0.0020163039476683514, 'subsample': 0.3991398553962028, 'min_child_weight': 4} fit started
# 2024-06-24 12:43:02,839 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:05,709 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:05,767 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:08,644 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:08,701 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:11,603 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:11,661 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:14,553 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:14,610 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:17,508 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:17,567 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:20,438 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:20,495 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:23,386 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:23,444 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:26,296 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:26,354 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:29,260 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:29,321 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:32,181 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:32,216 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 6, 'learning_rate': 0.0020163039476683514, 'subsample': 0.3991398553962028, 'min_child_weight': 4} with evaluated metrics: (0.0,)
#   0%|          | 2/100000 [00:29<817:36:18, 29.43s/trial, best loss: -0.7252151180777898]2024-06-24 12:43:32,233 - build_posterior_wrapper took 0.010968 seconds
# 2024-06-24 12:43:32,236 - TPE using 2/2 trials with best loss -0.725215
# 2024-06-24 12:43:32,244 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 4, 'learning_rate': 0.004388775780215801, 'subsample': 0.11527140252507681, 'min_child_weight': 14} fit started
# 2024-06-24 12:43:32,280 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:34,452 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:34,501 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:36,658 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:36,706 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:38,885 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:38,936 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:41,079 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:41,127 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:43,297 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:43,346 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:45,530 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:45,578 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:47,778 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:47,826 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:49,990 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:50,041 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:52,181 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:52,232 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:54,385 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:54,412 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 4, 'learning_rate': 0.004388775780215801, 'subsample': 0.11527140252507681, 'min_child_weight': 14} with evaluated metrics: (0.0,)
# 2024-06-24 12:43:54,415 - No progress made: 2 iteration on 3162. best_loss=0.00, best_loss_threshold=0.00, new_loss=0.00
#   0%|          | 3/100000 [00:51<717:06:51, 25.82s/trial, best loss: -0.7252151180777898]
# 2024-06-24 12:43:54,423 - SimultaneousTuner - Hyperparameters optimization finished
# 2024-06-24 12:43:54,428 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5} fit started
# 2024-06-24 12:43:54,469 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:56,381 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:56,428 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:43:58,347 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:43:58,392 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:00,356 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:00,402 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:02,314 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:02,359 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:04,256 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:04,301 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:06,218 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:06,263 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:08,181 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:08,227 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:10,135 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:10,182 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:12,095 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:12,141 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:14,057 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost
# 2024-06-24 12:44:14,080 - PipelineObjectiveEvaluate - Pipeline /n_xgboost_{'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5} with evaluated metrics: (-0.7252151180777898,)
# 2024-06-24 12:44:14,084 - SimultaneousTuner - Return init graph due to the fact that obtained metric 0.725 worse than initial (+ 0.05% deviation) 0.726
# 2024-06-24 12:44:14,087 - SimultaneousTuner - Final graph: {'depth': 1, 'length': 1, 'nodes': [xgboost]}
# xgboost - {'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 1, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5}
# 2024-06-24 12:44:14,089 - SimultaneousTuner - Final metric: 0.725
# 2024-06-24 12:44:14,093 - ApiComposer - Hyperparameters tuning finished
# 2024-06-24 12:44:14,728 - ApiComposer - Model generation finished
# 2024-06-24 12:44:14,748 - PipelineNode - Trying to fit pipeline node with operation: xgboost
# 2024-06-24 12:44:16,892 - FEDOT logger - Final pipeline was fitted
# 2024-06-24 12:44:16,895 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [xgboost]}
# xgboost - {'eval_metric': 'mlogloss', 'nthread': 1, 'n_jobs': 4, 'verbose': 0, 'max_depth': 3, 'learning_rate': 0.008355271922878766, 'subsample': 0.6292350424149393, 'min_child_weight': 5}
# 2024-06-24 12:44:16,898 - MemoryAnalytics - Memory consumption for finish in main session: current 44.1 MiB, max: 301.3 MiB
# {'depth': 1, 'length': 1, 'nodes': [xgboost]}

# %%
prediction = auto_model.predict_proba(features=test)
# Out:
# 2024-06-24 12:44:17,078 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost

# %%
sub.Target = prediction.ravel()
sub.to_csv("submission.csv", index=False)

# %%
prediction_valid = auto_model.predict_proba(features=valid)
# Out:
# 2024-06-24 12:44:17,343 - PipelineNode - Obtain prediction in pipeline node by operation: xgboost

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(valid.defects, prediction_valid)
# Out:
# 0.7846421211975648
