# %% [markdown]
# # Yolanda
#
# This dataset was utilized for a regression task, where
# the objective is to predict the values in column "101" based on the preceding features
#
# https://www.openml.org/search?type=data&status=active&id=4134&sort=runs

# %%
import openml
import sys, os
import pandas as pd
from scipy.io import arff
module_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))

if module_path not in sys.path:
    sys.path.insert(0, module_path)

# Load dataset by OpenML ID (e.g., abalone is 183)
dataset = openml.datasets.get_dataset(42705) 

X, y, _, _ = dataset.get_data(target=dataset.default_target_attribute)

TARGET = "101"
TEST_SIZE = 40000

# Combine into a single DataFrame
df = pd.concat([X, y.rename(TARGET)], axis=1)
# Preview the data
df
# Out:
#               1          2         3         4         5         6         7  \
# 0       45.5894   45.04220 -15.50100   4.49790   4.40198 -16.20820   3.95052
# 1       37.8328  -53.08580  -4.48305  -0.04554  13.59000 -24.49110  -4.13414
# 2       46.1868   -0.19721  36.28320   0.69286 -29.53300 -19.28370  -3.08122
# 3       37.0102 -179.60400  16.34480  -8.80111 -13.00460  -6.35464  -8.76096
# 4       47.2793   35.70250 -21.49700  28.83870  -6.70276 -13.94660  11.27730
# ...         ...        ...       ...       ...       ...       ...       ...
# 399995  48.9952   48.64530  30.18380  -8.72402  -0.22298 -26.27030  -6.81091
# 399996  39.8108  -79.78840 -69.40180 -20.15300  48.07950 -38.26150  31.31600
# 399997  44.9642   49.71120  47.84030   5.59156 -37.13160  -8.84819   3.16406
# 399998  48.5536   -6.19696  43.30010   4.19306 -31.21790 -14.69930  16.25190
# 399999  40.5328   -3.81962 -32.92720  25.12910   4.36242  10.10900 -16.69060
#
#                8         9        10  ...         92        93         94  \
# 0       -5.97738  -2.55198  -0.38542  ...   -33.4901  -16.7237   21.80580
# 1        0.35434  11.08170   2.05194  ...   137.9360  154.9830 -324.48300
# 2       -0.83528  17.66600   5.38864  ...   178.6990  791.3580   -6.65237
# 3        7.57259  29.74370  10.40090  ...  -523.5440   54.6238   10.61660
# 4        2.90669  -5.38827  18.10010  ...   165.9900    8.8037   47.25880
# ...          ...       ...       ...  ...        ...       ...        ...
# 399995   2.34358   3.10955   8.02655  ...   252.5940  -79.0788 -252.05000
# 399996  -3.31252 -13.11460  -8.62584  ...   225.0710  161.4130   84.63150
# 399997  -4.47937  -0.19186  -2.17976  ...   -12.1615  -51.4952  -37.87340
# 399998  -1.68831  -7.21603  -6.51143  ...   131.2180 -309.9680   38.54750
# 399999 -11.27170  19.29110   6.14263  ... -1155.1800  -31.6660   25.56780
#
#               95        96        97         98         99       100   101
# 0       1125.500 -10.42090   27.6556  -47.62800   67.99910  56.58150  2001
# 1        496.921  -6.97184  784.5490  103.64700  -15.72070 -39.07800  2004
# 2        530.638  -2.48853   72.9065    2.60052 -335.20800  28.44990  1985
# 3        567.117   1.23740  -95.0287  -64.92430   18.53050  39.53080  1977
# 4        808.163 -26.25220   12.1515  126.02200   93.65520   4.81204  2007
# ...          ...       ...       ...        ...        ...       ...   ...
# 399995   892.897 -15.20750  717.2470   67.60710  123.74400  92.91470  2004
# 399996   975.425  -3.91075  497.3380  315.60600 -169.30700  50.05870  2008
# 399997   321.190  -0.20097  -98.0655   71.43500    7.13634   5.58726  1975
# 399998   688.493 -26.51200   55.1129   15.60000  -32.84530   6.09536  2008
# 399999   731.423   0.41678   14.8802   -4.53714    7.66430  27.98970  2005
#
# [400000 rows x 101 columns]

# %%
# 3. Shuffle and add an ID column
df = df.sample(frac=1).reset_index(drop=True)
df.insert(0, "id", df.index)

# 4. Split data
test_df = df.tail(TEST_SIZE)
train_df = df.drop(test_df.index)

# 5. Drop target from test set
test_df_noring = test_df.drop(columns=[TARGET])

# 6. Save competition folder outputs
os.makedirs("competition", exist_ok=True)
train_df.to_csv("competition/train.csv", index=False)
test_df_noring.to_csv("competition/test.csv", index=False)

# 7. Create sample submission 
sample_submission = test_df[["id"]].copy()
sample_submission[TARGET] = 0
sample_submission.to_csv("competition/sample_submission.csv", index=False)

# 8. Save actual test targets
target_df = test_df[["id", TARGET]].copy()
target_df.to_csv("target.csv", index=False)

print("✅ Done: Files saved to 'competition/' and 'target.csv'")
# Out:
# ✅ Done: Files saved to 'competition/' and 'target.csv'
