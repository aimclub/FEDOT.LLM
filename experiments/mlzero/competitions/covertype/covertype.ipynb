# %%
from pathlib import Path
import sys

module_path = Path.cwd().parent.parent.absolute()

if str(module_path) not in sys.path:
    sys.path.insert(0, str(module_path))

from fedotllm.main import FedotAI
from fedotllm.handlers import JupyterOutput

dataset_path = Path.cwd() / "competition"
# Out:
# /home/vboxuser/miniconda3/envs/fedotllmtest/lib/python3.11/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-07-23 13:15:29,528 - HTTP Request: GET https://raw.githubusercontent.com/BerriAI/litellm/main/model_prices_and_context_window.json "HTTP/1.1 200 OK"

# %%
import shutil

output_path = Path.cwd() / 'output'
if output_path.exists():
    shutil.rmtree(output_path)
output_path.mkdir(parents=True, exist_ok=True)

# %%
description = \
"""
Your Goal:
It represents a multiclass classification problem aimed at predicting forest cover types from cartographic variables without remotely sensed data. Good luck!
Evaluation
The evaluation metric for this multiclass classification task is F1.
Submission File
The target variable ("Cover_Type" target) classifies areas into seven cover types, including Spruce/Fir, Lodgepole Pine, Ponderosa Pine, Cottonwood/Willow, Aspen, Douglas-fir, and Krummholz
Predictor variables include elevation, aspect, slope, and various soil characteristics represented as binary features.
"""
import os
with open("competition/description.txt", "w") as f:
    f.write(description)

# %%
fedot_ai = FedotAI(
        task_path=dataset_path,
        workspace=output_path,
        handlers=JupyterOutput().subscribe
    )

async for _ in fedot_ai.ask(message=description):
    continue
# Out:
# ================== HumanMessage ==================
#
#
# Your Goal:
# It represents a multiclass classification problem aimed at predicting forest cover types from cartographic variables without remotely sensed data. Good luck!
# Evaluation
# The evaluation metric for this multiclass classification task is F1.
# Submission File
# The target variable ("Cover_Type" target) classifies areas into seven cover types, including Spruce/Fir, Lodgepole Pine, Ponderosa Pine, Cottonwood/Willow, Aspen, Douglas-fir, and Krummholz
# Predictor variables include elevation, aspect, slope, and various soil characteristics represented as binary features.
#
#
# ================== HumanMessage ==================
#
# # Predicting Forest Cover Types: A Machine Learning Adventure 🌲
#
# ## Overview
# - **Problem Description**: We are tackling a multiclass classification problem that focuses on predicting types of forest cover based on various geographical and soil-related features from cartographic data.
# ...
