# %%
from pathlib import Path
import sys

module_path = Path.cwd().parent.parent.absolute()

if str(module_path) not in sys.path:
    sys.path.insert(0, str(module_path))

from fedotllm.main import FedotAI
from fedotllm.handlers import JupyterOutput

dataset_path = Path.cwd() / "competition"
dataset_path.mkdir(parents=True, exist_ok=True)
# Out:
# /Users/aleksejlapin/Work/STABLE-FedotLLM/.venv/lib/python3.11/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-07-23 20:19:31,194 - HTTP Request: GET https://raw.githubusercontent.com/BerriAI/litellm/main/model_prices_and_context_window.json "HTTP/1.1 200 OK"

# %%
import shutil

output_path = Path.cwd() / 'output'
if output_path.exists():
    shutil.rmtree(output_path)
output_path.mkdir(parents=True, exist_ok=True)

# %%
description = \
"""
Your Goal:
This dataset was utilized for a binary classification of molecular biological responses. Good luck!
Evaluation
The evaluation metric for this binary classification task is ROC AUC.
Submission File
Each row represents a molecule with a binary target indicating response presence (1) or absence (0). Target: "target" column.
"""
import os
with open("competition/description.txt", "w") as f:
    f.write(description)

# %%
fedot_ai = FedotAI(
        task_path=dataset_path,
        workspace=output_path,
        handlers=JupyterOutput().subscribe
    )

async for _ in fedot_ai.ask(message=description):
    continue
# Out:
# ================== HumanMessage ==================
#
#
# Your Goal:
# This dataset was utilized for a binary classification of molecular biological responses. Good luck!
# Evaluation
# The evaluation metric for this binary classification task is ROC AUC.
# Submission File
# Each row represents a molecule with a binary target indicating response presence (1) or absence (0). Target: "target" column.
#
#
# ================== HumanMessage ==================
#
# # Understanding the Bioinformatics Classification Model
#
# ### Overview
# - **Problem Description**: The goal is to determine whether certain molecular compounds produce a biological response. This type of binary classification plays an important role in drug discovery and development.
# - **Goal**: We aim to create a model that accurately predicts the presence (1) or absence (0) of biological response in various molecules, facilitating quicker and more effective drug development processes.
#
# ### Data Preprocessing
# Data preprocessing is crucial for preparing our information so that the ML model can learn effectively. Here’s a breakdown of the steps taken:
#
# - **Imputing Missing Values**:
#   - If there were any "missing" entries in our dataset, we used *mean imputation*, substituting missing values with the average. For instance, if the average income in a dataset was $50,000, that value would replace any missing income data.
# - **Feature Selection**:
#   - We selected only important features for our model. Features were filtered to keep those starting with 'D', which likely represent relevant measurements in our molecules.
#
# ### Pipeline Summary
# Our modeling process included various techniques and configurations, ensuring robust predictions. Here’s how it was structured:
#
# - **Model Types**:
#   - **Logistic Regression (Logit)**: A foundational model that predicts binary outcomes.
#   - **CatBoost**: This algorithm is great for categorical data and handles it efficiently.
#     - **Key Parameters**:
#       | Model      | Parameters                                                           | Explanation                                         |
#       |------------|----------------------------------------------------------------------|----------------------------------------------------|
#       | CatBoost   | num_trees: 3000, learning_rate: 0.03, max_depth: 5, l2_leaf_reg: 0.01 | Chosen for its ability to manage categorical features. |
#   - **XGBoost** and **LightGBM (LGBM)**: These are powerful frameworks for gradient boosting, optimized for speed and performance.
#
# - **Model Training**: The models were trained using standardized techniques and parameters, ensuring they learned effectively.
#
# ### Code Highlights:
# Here are snippets that showcase the core functionality of the model:
#
# ```python
# # Data transformation to prepare for model training
# def transform_data(dataset: pd.DataFrame) -> Tuple[np.ndarray, np.ndarray]:
#     # Impute missing values
#     numeric_imputer = SimpleImputer(strategy="mean")
#     features[numeric_cols] = numeric_imputer.fit_transform(features[numeric_cols])
#     # Drop irrelevant columns
#     features = features[important_columns]
#     return features.values, target
# ```
#
# - **What It Does**: This function takes the data, fills in missing values for numeric features, and filters out unnecessary columns, ensuring only the most relevant data is used.
#
# ```python
# # AutoML Model Training
# model = Fedot(problem=TaskTypesEnum.classification.value,
#         timeout=30,
#         seed=42,
#         cv_folds=5,
#         preset='auto',
#         metric='roc_auc'
# )
# ```
#
# - **Purpose**: This snippet initializes the model with classification tasks and sets performance evaluations to focus on the area under the ROC curve (AUC-ROC), a key metric for understanding model efficacy.
#
# ### Metrics
# - The model's performance was quantified using the **ROC AUC** score of **0.868**.
#   - **Interpretation**: The AUC-ROC score ranges from 0 to 1, with values closer to 1 indicating better model performance. A score of 0.868 indicates the model can effectively distinguish between molecules with and without biological responses.
#
# ### Takeaways
# - This ML model demonstrates its prowess in predicting biological responses with an impressive ROC AUC score. This high performance suggests significant potential for real-world applications, particularly in the realms of pharmaceuticals and biotechnology, where understanding molecular responses can streamline the drug development process and lead to more effective therapies.
#
# Engaging with these results highlights the ability of machine learning to drive advancements in healthcare and research, offering tools to make sense of complex biological data.
