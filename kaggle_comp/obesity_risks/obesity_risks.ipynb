# %%
import sys
import os

module_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))

if module_path not in sys.path:
    sys.path.insert(0, module_path)

from examples.runner import run_fedot_ai_competition

competition_name = "playground-series-s4e2"
dataset_path = os.path.join(os.getcwd(), "competition")
output_path = os.path.join(os.getcwd(), 'output')
await run_fedot_ai_competition(dataset_path=dataset_path, output_path=output_path, competition_name=competition_name, description_file="overview.txt", model="github/gpt-4o", log_file=f"{competition_name}.log")
# Out:
# /Users/aleksejlapin/Work/STABLE-FedotLLM/.venv/lib/python3.10/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ...
# Dataset downloaded and extracted to /Users/aleksejlapin/Work/STABLE-FedotLLM/kaggle_comp/obesity_risks/competition
# Description preview:
# # Multi-Class Prediction of Obesity Risk
#
# Playground Series - Season 4, Episode 2
#
# ![](https://www.k...
# ======================================== FEDOT.LLM START ========================================
# Running FedotAI analysis...
# 2025-05-30 01:48:59,826 - FEDOTLLM - INFO - Running problem reflection
# 2025-05-30 01:50:07,602 - FEDOTLLM - INFO - Running generate automl config
# 2025-05-30 01:50:11,142 - FEDOTLLM - INFO - Running select skeleton
# ...
